# %%
# 导包
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from collections import defaultdict

# %%
orderHistory = pd.read_csv('./data/orderHistory_train.csv')
orderHistory.head()
# Out:
#          userid  orderid   orderTime  orderType city country continent
# 0  100000000013  1000015  1481714516          0   柏林      德国        欧洲
# 1  100000000013  1000014  1501959643          0  旧金山      美国       北美洲
# 2  100000000393  1000033  1499440296          0   巴黎      法国        欧洲
# 3  100000000459  1000036  1480601668          0   纽约      美国       北美洲
# 4  100000000459  1000034  1479146723          0  巴厘岛   印度尼西亚        亚洲

# %%
# 统计去向
def totalLocationMap(featureName, fileName):
    df = pd.read_csv(fileName)
    datas = df[['userid', 'orderType', featureName]].values
    QLocalMap = {}
    allLocalMap = {}
    proMap = {}
    userSet = set()
    for data in datas:
        user = str(int(data[0]))
        orderType = str(data[1])
        add  = str(data[2])
        if add not in allLocalMap:
            QLocalMap[add] = 0
            allLocalMap[add] = 0
       
        if (orderType == '1'): QLocalMap[add] += 1
        allLocalMap[add] += 1
        userSet.add(user)
    for key in allLocalMap.keys():
        proMap[key] = QLocalMap[key] / allLocalMap[key]
    print(len(userSet))
    return QLocalMap, allLocalMap, proMap, userSet

# city 统计
QLocalMap, allLocalMap, proMap, userSet = totalLocationMap('city', './data/orderHistory_train.csv')
QLocalMap = sorted(QLocalMap.items(), key=lambda val:val[1],reverse=True)

proMap = sorted(proMap.items(), key=lambda val:val[1],reverse=True)
print(proMap)

def checkIfAllHistoryUserInTrain(userSetInHistory, fileName):
    train = pd.read_csv(fileName)
    datas = train['userid'].values
    cnt = 0
    userInHistory = set()
    for user in datas:
        user = str(int(user))
        if user not in userSetInHistory:
            cnt += 1
        else:
            userInHistory.add(user)
    if cnt == 0:
        print("userInHistory is all in train data!")
    else:
        print("sorry! userInHistory is not all in train data! The number is ", cnt)
    return userInHistory

userInHistory = checkIfAllHistoryUserInTrain(userSet, './data/train.csv')
print(len(userInHistory))
# Out:
# 10637
# [('冲绳市', 1.0), ('北海道--旭川', 1.0), ('毛里求斯', 1.0), ('因特拉肯', 1.0), ('圣保罗', 1.0), ('垦丁', 1.0), ('成田市', 1.0), ('巴伦西亚', 1.0), ('那不勒斯', 1.0), ('神户', 1.0), ('洞爷湖', 1.0), ('台南', 1.0), ('巴斯', 1.0), ('岐阜县', 1.0), ('宿务', 1.0), ('华欣', 1.0), ('马拉加', 1.0), ('萨尔茨堡', 1.0), ('长崎', 1.0), ('轻井泽', 1.0), ('阿里山', 1.0), ('科隆', 1.0), ('戛纳', 1.0), ('格拉纳达', 1.0), ('新北', 1.0), ('箱根', 1.0), ('哈尔施塔特', 1.0), ('约克', 1.0), ('温莎', 1.0), ('新竹', 1.0), ('大西洋城', 1.0), ('富良野', 1.0), ('牛津', 1.0), ('摩纳哥', 1.0), ('拉科鲁尼亚', 1.0), ('汉密尔顿', 1.0), ('富士山', 1.0), ('卢塞恩', 1.0), ('宜兰', 1.0), ('嘉义', 1.0), ('利瓦绿洲', 1.0), ('金泽', 1.0), ('横滨', 1.0), ('御殿场市', 1.0), ('蒂卡波湖', 1.0), ('阿尔勒', 1.0), ('云顶高原', 1.0), ('富士河口湖', 1.0), ('南投', 1.0), ('科茨沃尔德', 1.0), ('千叶', 1.0), ('芭堤雅', 1.0), ('北海道--函馆', 1.0), ('富山市', 1.0), ('雷克雅未克', 1.0), ('贝尔法斯特', 1.0), ('星野度假村', 1.0), ('熊本市', 1.0), ('福森', 1.0), ('北海道--小樽', 1.0), ('谢菲尔德', 1.0), ('北海道--登别', 1.0), ('千叶市', 1.0), ('波尔图', 1.0), ('考文垂', 1.0), ('奈良', 1.0), ('花莲', 0.9242424242424242), ('塞维利亚', 0.8333333333333334), ('皇后镇', 0.7777777777777778), ('马赛', 0.75), ('阿维尼翁', 0.75), ('佛罗伦萨', 0.6764705882352942), ('华沙', 0.6666666666666666), ('日内瓦', 0.625), ('哥本哈根', 0.6153846153846154), ('苏黎世', 0.6111111111111112), ('京都', 0.5972222222222222), ('布达佩斯', 0.5714285714285714), ('维也纳', 0.5555555555555556), ('济州岛', 0.5353535353535354), ('圣彼得堡', 0.5172413793103449), ('伊尔库茨克', 0.5), ('夏威夷茂宜岛', 0.5), ('广岛', 0.5), ('里斯本', 0.47619047619047616), ('布拉格', 0.47058823529411764), ('仰光', 0.42857142857142855), ('布鲁塞尔', 0.4166666666666667), ('莫斯科', 0.40476190476190477), ('伊斯坦布尔', 0.4), ('斯德哥尔摩', 0.4), ('慕尼黑', 0.375), ('曼彻斯特', 0.3684210526315789), ('柏林', 0.34615384615384615), ('冲绳--那霸', 0.34210526315789475), ('釜山', 0.3333333333333333), ('汉堡', 0.3333333333333333), ('开罗', 0.3333333333333333), ('威尼斯', 0.3181818181818182), ('赫尔辛基', 0.3181818181818182), ('马德里', 0.3108108108108108), ('北海道--札幌', 0.29949238578680204), ('法兰克福', 0.2857142857142857), ('巴厘岛', 0.2803532008830022), ('迪拜', 0.2777777777777778), ('米兰', 0.2740740740740741), ('盐湖城', 0.2727272727272727), ('卡尔加里', 0.2692307692307692), ('尼斯', 0.2619047619047619), ('澳门', 0.2608695652173913), ('费城', 0.2564102564102564), ('阿姆斯特丹', 0.2553191489361702), ('圣地亚哥', 0.25), ('雅典', 0.25), ('奥斯陆', 0.25), ('台中', 0.25), ('波尔多', 0.25), ('巴塞罗那', 0.23846153846153847), ('福冈', 0.23809523809523808), ('蒙特利尔', 0.225), ('维多利亚', 0.2222222222222222), ('暹粒', 0.21875), ('迈阿密', 0.21428571428571427), ('大阪', 0.21358267716535434), ('名古屋', 0.20689655172413793), ('夏威夷大岛', 0.2), ('休斯敦', 0.2), ('罗马', 0.1935483870967742), ('阿布扎比', 0.19047619047619047), ('杜塞尔多夫', 0.18181818181818182), ('爱丁堡', 0.18181818181818182), ('旧金山', 0.18088737201365188), ('东京', 0.17946003176283748), ('高雄', 0.1746031746031746), ('静冈县', 0.16666666666666666), ('洛杉矶', 0.16666666666666666), ('巴黎', 0.16176470588235295), ('多伦多', 0.16153846153846155), ('曼谷', 0.1562881562881563), ('伦敦', 0.15625), ('波士顿', 0.15343915343915343), ('西雅图', 0.15294117647058825), ('芝加哥', 0.14893617021276595), ('墨尔本', 0.14494518879415347), ('华盛顿', 0.13986013986013987), ('珀斯', 0.13793103448275862), ('胡志明市', 0.13725490196078433), ('夏威夷欧胡岛（檀香山）', 0.12941176470588237), ('首尔', 0.12941176470588237), ('芽庄', 0.1276595744680851), ('底特律', 0.125), ('渥太华', 0.125), ('温哥华', 0.12234042553191489), ('台北', 0.12195121951219512), ('都柏林', 0.1111111111111111), ('布里斯班', 0.10526315789473684), ('基督城', 0.10526315789473684), ('阿德莱德', 0.10344827586206896), ('清迈', 0.10038610038610038), ('悉尼', 0.09951690821256039), ('拉斯维加斯', 0.09917355371900827), ('吉隆坡', 0.09851301115241635), ('奥克兰', 0.09333333333333334), ('纽约', 0.09139307897071872), ('岘港', 0.08), ('黄金海岸', 0.06896551724137931), ('丹佛', 0.0625), ('沙巴--亚庇', 0.058823529411764705), ('布法罗', 0.058823529411764705), ('亚特兰大', 0.058823529411764705), ('槟城', 0.0546875), ('凯恩斯', 0.05405405405405406), ('楠迪', 0.045454545454545456), ('新山', 0.041666666666666664), ('香港', 0.036786060019361085), ('新加坡', 0.02942694889003614), ('兰卡威', 0.02040816326530612), ('普吉岛', 0.019178082191780823), ('奥兰多', 0.014925373134328358), ('霍巴特', 0.0), ('苏梅岛', 0.0 ...
# userInHistory is all in train data!
# 4103

# %%
# 国家 统计
QLocalMap, allLocalMap, proMap, userSet = totalLocationMap('country', './data/orderHistory_train.csv')
QLocalMap = sorted(QLocalMap.items(), key=lambda val:val[1],reverse=True)

proMap = sorted(proMap.items(), key=lambda val:val[1],reverse=True)
print(proMap)
# Out:
# 10637
# [('毛里求斯', 1.0), ('巴西', 1.0), ('冰岛', 1.0), ('波兰', 0.6666666666666666), ('瑞士', 0.6551724137931034), ('丹麦', 0.6153846153846154), ('奥地利', 0.5862068965517241), ('匈牙利', 0.5714285714285714), ('葡萄牙', 0.5), ('捷克', 0.47058823529411764), ('俄罗斯', 0.4520547945205479), ('缅甸', 0.42857142857142855), ('比利时', 0.4166666666666667), ('土耳其', 0.4), ('瑞典', 0.38461538461538464), ('德国', 0.336734693877551), ('埃及', 0.3333333333333333), ('芬兰', 0.3181818181818182), ('西班牙', 0.29439252336448596), ('意大利', 0.28448275862068967), ('印度尼西亚', 0.27973568281938327), ('阿联酋', 0.26785714285714285), ('中国澳门', 0.2608695652173913), ('荷兰', 0.2553191489361702), ('挪威', 0.25), ('希腊', 0.25), ('日本', 0.23995440296380735), ('韩国', 0.22321428571428573), ('中国台湾', 0.2032640949554896), ('法国', 0.17904509283819628), ('英国', 0.1721763085399449), ('菲律宾', 0.16666666666666666), ('柬埔寨', 0.16666666666666666), ('加拿大', 0.15920398009950248), ('新西兰', 0.13812154696132597), ('美国', 0.1297457906899967), ('爱尔兰', 0.1111111111111111), ('澳大利亚', 0.1109278350515464), ('越南', 0.10869565217391304), ('泰国', 0.10861182519280206), ('马来西亚', 0.08735150244584207), ('斐济', 0.045454545454545456), ('中国香港', 0.036786060019361085), ('新加坡', 0.02942694889003614), ('中国', 0.0), ('卡塔尔', 0.0), ('尼泊尔', 0.0), ('墨西哥', 0.0), ('老挝', 0.0), ('南非', 0.0), ('摩洛哥', 0.0)]

# %%
# 大陆 统计
QLocalMap, allLocalMap, proMap, userSet = totalLocationMap('continent', './data/orderHistory_train.csv')
QLocalMap = sorted(QLocalMap.items(), key=lambda val:val[1],reverse=True)

proMap = sorted(proMap.items(), key=lambda val:val[1],reverse=True)
print(proMap)
# Out:
# 10637
# [('南美洲', 1.0), ('非洲', 0.2727272727272727), ('欧洲', 0.2449544914918876), ('亚洲', 0.1488302638128422), ('北美洲', 0.13315850815850816), ('大洋洲', 0.11225266362252663)]

# %%
# 测试集

# city 统计
QLocalMap, allLocalMap, proMap, userSet = totalLocationMap('city', './data/test/orderHistory_test.csv')
QLocalMap = sorted(QLocalMap.items(), key=lambda val:val[1],reverse=True)
print(len(userSet))

proMap = sorted(proMap.items(), key=lambda val:val[1],reverse=True)
print(proMap)

userInHistory = checkIfAllHistoryUserInTrain(userSet, './data/test/test.csv')
print(len(userInHistory))
# Out:
# 2686
# 2686
# [('和歌山', 1.0), ('千岁', 1.0), ('摩纳哥', 1.0), ('北海道--旭川', 1.0), ('布鲁塞尔', 1.0), ('约克', 1.0), ('垦丁', 1.0), ('湖区', 1.0), ('利物浦', 1.0), ('万象', 1.0), ('拜县', 1.0), ('嘉义', 1.0), ('莱顿', 1.0), ('夏威夷茂宜岛', 1.0), ('开罗', 1.0), ('巴斯', 1.0), ('华欣', 1.0), ('宜兰', 1.0), ('芭堤雅', 1.0), ('阿里山', 1.0), ('汉诺威', 1.0), ('戛纳', 1.0), ('神户', 1.0), ('美因茨', 1.0), ('富士五湖地区', 1.0), ('二世古', 1.0), ('圣保罗', 1.0), ('箱根', 1.0), ('北海道--小樽', 1.0), ('大城', 1.0), ('夏威夷大岛', 1.0), ('贝尔法斯特', 1.0), ('熊本市', 1.0), ('南投', 1.0), ('剑桥', 1.0), ('格拉斯哥', 1.0), ('富士山', 1.0), ('奥斯陆', 1.0), ('花莲', 0.9), ('尼斯', 0.8333333333333334), ('慕尼黑', 0.8181818181818182), ('曼彻斯特', 0.6666666666666666), ('里斯本', 0.6666666666666666), ('圣彼得堡', 0.625), ('莫斯科', 0.6), ('台中', 0.5833333333333334), ('暹粒', 0.5555555555555556), ('霍巴特', 0.5), ('阿布扎比', 0.5), ('阿维尼翁', 0.5), ('底特律', 0.5), ('日内瓦', 0.5), ('斯德哥尔摩', 0.5), ('柏林', 0.5), ('布达佩斯', 0.5), ('圣地亚哥', 0.4444444444444444), ('冲绳--那霸', 0.4166666666666667), ('赫尔辛基', 0.4), ('济州岛', 0.391304347826087), ('巴塞罗那', 0.375), ('京都', 0.3673469387755102), ('阿姆斯特丹', 0.35), ('维也纳', 0.3333333333333333), ('卡尔加里', 0.3333333333333333), ('爱丁堡', 0.3333333333333333), ('法兰克福', 0.3333333333333333), ('旧金山', 0.32142857142857145), ('拉斯维加斯', 0.3125), ('罗马', 0.30303030303030304), ('迪拜', 0.28125), ('奥克兰', 0.28), ('佛罗伦萨', 0.25), ('金边', 0.25), ('渥太华', 0.25), ('名古屋', 0.23076923076923078), ('巴厘岛', 0.22115384615384615), ('东京', 0.20907297830374755), ('高雄', 0.1875), ('沙巴--亚庇', 0.18421052631578946), ('北海道--札幌', 0.17647058823529413), ('布拉格', 0.16666666666666666), ('波尔多', 0.16666666666666666), ('墨尔本', 0.14358974358974358), ('曼谷', 0.14344262295081966), ('马德里', 0.14285714285714285), ('雅典', 0.14285714285714285), ('澳门', 0.14285714285714285), ('伦敦', 0.13157894736842105), ('大阪', 0.13025210084033614), ('巴黎', 0.12987012987012986), ('波士顿', 0.12903225806451613), ('黄金海岸', 0.125), ('悉尼', 0.12048192771084337), ('洛杉矶', 0.11764705882352941), ('首尔', 0.11392405063291139), ('哥本哈根', 0.1111111111111111), ('奥兰多', 0.1111111111111111), ('米兰', 0.10344827586206896), ('苏梅岛', 0.1), ('温哥华', 0.09090909090909091), ('吉隆坡', 0.08561643835616438), ('纽约', 0.08085106382978724), ('清迈', 0.078125), ('台北', 0.07076923076923076), ('华盛顿', 0.06666666666666667), ('夏威夷欧胡岛（檀香山）', 0.058823529411764705), ('芝加哥', 0.05263157894736842), ('多伦多', 0.05263157894736842), ('西雅图', 0.047619047619047616), ('布里斯班', 0.0392156862745098), ('香港', 0.03773584905660377), ('新加坡', 0.03728070175438596), ('普吉岛', 0.030303030303030304), ('凯恩斯', 0.0), ('新山', 0.0), ('堪培拉', 0.0), ('华沙', 0.0), ('珀斯', 0.0), ('伯明翰', 0.0), ('苏黎世', 0.0), ('费城', 0.0), ('河内', 0.0), ('伊尔库茨克', 0.0), ('基督城', 0.0), ('仰光', 0.0), ('阿德莱德', 0.0), ('丹佛', 0.0), ('岘港', 0.0), ('楠迪', 0.0), ('塞班岛', 0.0), ('福冈', 0.0), ('槟城', 0.0), ('维多利亚', 0.0), ('釜山', 0.0), ('广岛', 0.0), ('静冈县', 0.0), ('布法罗', 0.0), ('胡志明市', 0.0), ('亚特兰大', 0.0), ('蒙特利尔', 0.0), ('雷克雅未克', 0.0), ('威尼斯', 0.0), ('兰卡威', 0.0), ('芽庄', 0.0), ('甲米', 0.0), ('马尼拉', 0.0), ('迈阿密', 0.0), ('巴尔的摩', 0.0), ('达拉斯', 0.0), ('墨西哥城', 0.0), ('休斯敦', 0.0)]
# sorry! userInHistory is not all in train data! The number is  7390
# 2686

# %%
# 从现有训练集加入地点特征，所有用户均在OrderHistory 所以可以全部用来增加新特征
