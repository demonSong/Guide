# %%
# 导包
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC, LinearSVC
from sklearn import tree, datasets, svm

# %%
# 模型调参
train = pd.read_csv('./data/train.csv')
examples = train[['total', 'ratio', 'locFeature']]
labels   = train[['label']]
X_train = examples
y_train = labels
# X_train, X_test, y_train, y_test = train_test_split(examples, labels, test_size=0.01, random_state=0)
c, r = y_train.shape
print(c, r)
y_train = np.array(y_train).reshape(c,)

param ={'n_estimators':range(1,500,10)}  
gsearch1= GridSearchCV(estimator = RandomForestClassifier(),   
                       param_grid =param,scoring='roc_auc',cv=5) # 5折交叉
gsearch1.fit(X_train,y_train)  
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# 10637 1
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.80604, std: 0.00808, params: {'n_estimators': 1},
#   mean: 0.80764, std: 0.00980, params: {'n_estimators': 11},
#   mean: 0.80912, std: 0.00900, params: {'n_estimators': 21},
#   mean: 0.80747, std: 0.00731, params: {'n_estimators': 31},
#   mean: 0.80743, std: 0.00941, params: {'n_estimators': 41},
#   mean: 0.80742, std: 0.00822, params: {'n_estimators': 51},
#   mean: 0.80769, std: 0.00874, params: {'n_estimators': 61},
#   mean: 0.80929, std: 0.00803, params: {'n_estimators': 71},
#   mean: 0.80889, std: 0.00964, params: {'n_estimators': 81},
#   mean: 0.80869, std: 0.00795, params: {'n_estimators': 91},
#   mean: 0.80965, std: 0.00729, params: {'n_estimators': 101},
#   mean: 0.80843, std: 0.00860, params: {'n_estimators': 111},
#   mean: 0.80731, std: 0.00813, params: {'n_estimators': 121},
#   mean: 0.80847, std: 0.00860, params: {'n_estimators': 131},
#   mean: 0.80765, std: 0.00822, params: {'n_estimators': 141},
#   mean: 0.80850, std: 0.00795, params: {'n_estimators': 151},
#   mean: 0.80886, std: 0.00727, params: {'n_estimators': 161},
#   mean: 0.80805, std: 0.00869, params: {'n_estimators': 171},
#   mean: 0.80831, std: 0.00798, params: {'n_estimators': 181},
#   mean: 0.80856, std: 0.00808, params: {'n_estimators': 191},
#   mean: 0.80732, std: 0.00834, params: {'n_estimators': 201},
#   mean: 0.80861, std: 0.00836, params: {'n_estimators': 211},
#   mean: 0.80894, std: 0.00869, params: {'n_estimators': 221},
#   mean: 0.80957, std: 0.00795, params: {'n_estimators': 231},
#   mean: 0.80856, std: 0.00789, params: {'n_estimators': 241},
#   mean: 0.80791, std: 0.00835, params: {'n_estimators': 251},
#   mean: 0.80806, std: 0.00848, params: {'n_estimators': 261},
#   mean: 0.80794, std: 0.00901, params: {'n_estimators': 271},
#   mean: 0.80782, std: 0.00899, params: {'n_estimators': 281},
#   mean: 0.80802, std: 0.00879, params: {'n_estimators': 291},
#   mean: 0.80883, std: 0.00811, params: {'n_estimators': 301},
#   mean: 0.80753, std: 0.00887, params: {'n_estimators': 311},
#   mean: 0.80858, std: 0.00851, params: {'n_estimators': 321},
#   mean: 0.80807, std: 0.00853, params: {'n_estimators': 331},
#   mean: 0.80756, std: 0.00836, params: {'n_estimators': 341},
#   mean: 0.80839, std: 0.00851, params: {'n_estimators': 351},
#   mean: 0.80771, std: 0.00825, params: {'n_estimators': 361},
#   mean: 0.80876, std: 0.00875, params: {'n_estimators': 371},
#   mean: 0.80796, std: 0.00831, params: {'n_estimators': 381},
#   mean: 0.80839, std: 0.00802, params: {'n_estimators': 391},
#   mean: 0.80890, std: 0.00815, params: {'n_estimators': 401},
#   mean: 0.80797, std: 0.00785, params: {'n_estimators': 411},
#   mean: 0.80830, std: 0.00814, params: {'n_estimators': 421},
#   mean: 0.80814, std: 0.00862, params: {'n_estimators': 431},
#   mean: 0.80845, std: 0.00859, params: {'n_estimators': 441},
#   mean: 0.80846, std: 0.00806, params: {'n_estimators': 451},
#   mean: 0.80845, std: 0.00846, params: {'n_estimators': 461},
#   mean: 0.80874, std: 0.00835, params: {'n_estimators': 471},
#   mean: 0.80754, std: 0.00806, params: {'n_estimators': 481},
#   mean: 0.80839, std: 0.00833, params: {'n_estimators': 491}],
#  {'n_estimators': 101},
#  0.80964708857773149)

# %%
# 可视化训练参数
def plotGridSearch(gsearch, paramsName):
        fig,(axis1,axis2) = plt.subplots(1,2,figsize = (15,5))
        mean = [s[1] for s in gsearch1.grid_scores_]
        std  = [np.std(s[2]) for s in gsearch1.grid_scores_]
        params = [s[0][paramsName] for s in gsearch1.grid_scores_]

        plt.plot(params, mean)
        plt.xlabel(paramsName)
        plt.ylabel('mean')
        plt.title('Mean Accuracy')
        plt.sca(axis1)
        
        plt.plot(params, std)
        plt.xlabel(paramsName)
        plt.ylabel('std')
        plt.title('std')
        plt.sca(axis2)
        # 展示图片
        plt.show()
        
plotGridSearch(gsearch1, 'n_estimators')
# Out:
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
# 模型调参 gini or entropy
train = pd.read_csv('./data/train.csv')
examples = train[['total', 'ratio', 'locFeature']]
labels   = train[['label']]
X_train = examples
y_train = labels
# X_train, X_test, y_train, y_test = train_test_split(examples, labels, test_size=0.01, random_state=0)
c, r = y_train.shape
y_train = np.array(y_train).reshape(c,)

param ={'criterion': ('entropy', 'gini')}  
gsearch1= GridSearchCV(estimator = RandomForestClassifier(n_estimators = 101),   
                       param_grid =param,scoring='roc_auc',cv=5) # 5折交叉验证
gsearch1.fit(X_train,y_train)  
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.80779, std: 0.00847, params: {'criterion': 'entropy'},
#   mean: 0.80765, std: 0.00814, params: {'criterion': 'gini'}],
#  {'criterion': 'entropy'},
#  0.80778532513163559)

# %%
# 模型调参 最大特征数 后期可以增大特征数
train = pd.read_csv('./data/train.csv')
examples = train[['total', 'ratio', 'locFeature']]
labels   = train[['label']]
X_train = examples
y_train = labels
X_train, X_test, y_train, y_test = train_test_split(examples, labels, test_size=0.33, random_state=0)
c, r = y_train.shape
y_train = np.array(y_train).reshape(c,)

param ={'max_features': range(1,4,1)}  
gsearch1= GridSearchCV(estimator = RandomForestClassifier(n_estimators = 101,criterion = 'entropy'),   
                       param_grid =param,scoring='roc_auc',cv=5) # 5折交叉验证
gsearch1.fit(X_train,y_train)  
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_

plotGridSearch(gsearch1, 'max_features')
# Out:
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %%
# 模型调参 递归深度
train = pd.read_csv('./data/train.csv')
examples = train[['total', 'ratio', 'locFeature']]
labels   = train[['label']]
X_train = examples
y_train = labels
X_train, X_test, y_train, y_test = train_test_split(examples, labels, test_size=0.33, random_state=0)
c, r = y_train.shape
y_train = np.array(y_train).reshape(c,)

param ={'max_depth': range(10,101,10)}  
gsearch1= GridSearchCV(estimator = RandomForestClassifier(n_estimators = 101,criterion = 'entropy', max_features = 3),   
                       param_grid =param,scoring='roc_auc',cv=5) # 5折交叉验证
gsearch1.fit(X_train,y_train)  
gsearch1.grid_scores_ 
# 得分最高的模型
print(gsearch1.best_params_, gsearch1.best_score_)

plotGridSearch(gsearch1, 'max_depth')
# Out:
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# {'max_depth': 90} 0.806806566067

# %%
# 模型训练
train = pd.read_csv('./data/train.csv')
examples = train[['total', 'ratio', 'locFeature']]
labels   = train[['label']]
X_train = examples
y_train = labels
c, r = y_train.shape
y_train = np.array(y_train).reshape(c,)

cls = RandomForestClassifier(n_estimators = 71, criterion = 'entropy', max_features = 3, max_depth = 90)
cls.fit(X_train, y_train)
score = cls.score(X_train, y_train)
print(score)

test = pd.read_csv('./data/test/test.csv')
x_test = test[['total', 'ratio', 'locFeature']]
predicts  = cls.predict(x_test)

submission = pd.DataFrame({
    "orderType" : predicts,
    "userid" : test["userid"]
}, columns = ['userid', 'orderType'])

submission.to_csv('test.csv',index = False)
# Out:
# 0.894237096926
